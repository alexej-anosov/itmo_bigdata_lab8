# %%
# !wget https://static.openfoodfacts.org/data/en.openfoodfacts.org.products.csv.gz
# Out:
# --2024-08-19 14:30:47--  https://static.openfoodfacts.org/data/en.openfoodfacts.org.products.csv.gz
# Resolving static.openfoodfacts.org (static.openfoodfacts.org)... 213.36.253.214
# Connecting to static.openfoodfacts.org (static.openfoodfacts.org)|213.36.253.214|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 949902034 (906M) [application/octet-stream]
# Saving to: ‘en.openfoodfacts.org.products.csv.gz.1’
#
# en.openfoodfacts.or 100%[===================>] 905.90M  14.6MB/s    in 57s
#
# 2024-08-19 14:31:45 (15.8 MB/s) - ‘en.openfoodfacts.org.products.csv.gz.1’ saved [949902034/949902034]

# %%
# !gunzip -c /root/itmo_bigdata_lab5/notebooks/en.openfoodfacts.org.products.csv.gz > ../data/en.openfoodfacts.org.products.csv

# %%
import pandas as pd

    
df = pd.read_csv('../data/en.openfoodfacts.org.products.csv', sep='\t', nrows=200_000)
df
# Out:
# /tmp/ipykernel_3294/1371276211.py:4: DtypeWarning: Columns (0,11,17,31,32,33,35,72) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/en.openfoodfacts.org.products.csv', sep='\t', nrows=200_000)
#                           code  \
# 0            00000000000000225
# 1       0000000000000207025004
# 2         00000000000003429145
# 3         00000000000026772226
# 4                0000000000017
# ...                        ...
# 199995                  440783
# 199996                  440790
# 199997             44079710064
# 199998             44082003948
# 199999             44082022116
#
#                                                       url  \
# 0       http://world-en.openfoodfacts.org/product/0000...
# 1       http://world-en.openfoodfacts.org/product/0000...
# 2       http://world-en.openfoodfacts.org/product/0000...
# 3       http://world-en.openfoodfacts.org/product/0000...
# ...

# %%
df = df[['code', 'product_name', *df.columns[[df[column].dtype!='object' for column in df.columns]]]]

# %%
df = df[df.columns[df.isna().sum()<100000]]

# %%
df = df.dropna(axis=0).reset_index(drop=True)

# %%
df = df.sample(10000).reset_index(drop=True)

# %%
df
# Out:
#              code                                 product_name   created_t  \
# 0     41512117534                       Homestyle Orange Juice  1489072290
# 1     14100071013      Pepperidge farm, 100% whole wheat bread  1576680826
# 2     24300043017                           Oatmeal Creme Pies  1489068137
# 3     14500017253             Power Blend Black Rice & Edamame  1489141010
# 4     30034932671                Thai Style Sweet Chili Hummus  1587676161
# ...           ...                                          ...         ...
# 9995  29839100170                      Ice Cream & Sherbet Bar  1489058469
# 9996  41196110685  Loaded Potato Soup With Fried Onion Strings  1587669708
# 9997  21908112541         Protein peanut butter chocolate bars  1587672777
# 9998  11110745033                                 Pecan Pieces  1489068943
# 9999  37014000566    Salted Peanuts + Dark Chocolate 60% Cocoa  1587674191
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 23 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   code                                                   10000 non-null  object
#  1   product_name                                           10000 non-null  object
#  2   created_t                                              10000 non-null  int64
#  3   last_modified_t                                        10000 non-null  int64
#  4   last_updated_t                                         10000 non-null  float64
#  5   serving_quantity                                       10000 non-null  float64
#  6   additives_n                                            10000 non-null  float64
#  7   nutriscore_score                                       10000 non-null  float64
# ...

# %%
df.to_csv('../data/subset.csv', index=False)
